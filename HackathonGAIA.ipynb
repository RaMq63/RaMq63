# %% [markdown]
# <a href="https://colab.research.google.com/github/RaMq63/RaMq63/blob/main/HackathonGAIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### StoryLand ( GAIA hackathoon project )
# **team : the rubber duck** 🦆

# %% [markdown]
# the installations

# %%
# !pip install diffusers==0.11.1
# !pip install transformers scipy ftfy accelerate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.9/524.9 kB 21.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 15.0 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 90.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 25.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 114.5 MB/s eta 0:00:00
# ...

# %%
! pip install elevenlabs
! pip install elevenlabs -U
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 49.2 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
! pip install cohere
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 18.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# imports:

# %%
import torch
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", torch_dtype=torch.float16)
# Out:
# ...
# Fetching 20 files:   0%|          | 0/20 [00:00<?, ?it/s]
# ...
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# The config attributes {'scaling_factor': 0.18215} were passed to AutoencoderKL, but are not expected and will be ignored. Please verify your config.json configuration file.

# %%
import cohere  
co = cohere.Client('MYWu814nAU5Yp0KQdlS6GZGi49Q8Ao8CDTp4lLdA')

# %%
from elevenlabs import generate, play, set_api_key

# %% [markdown]
# move the pipeline to GPU to have faster inference.

# %%
pipe = pipe.to("cuda")

# %% [markdown]
# take input from user

# %%
Name = input()
charecter = input()
title = input()
# Out:
# sara
# cat
# cat with a hat

# %% [markdown]
# generate story

# %%
response = co.generate(
    model='command-nightly',
    prompt='write a story about ' + charecter + ',' + title +' and ' + Name,
    max_tokens=200,
    temperature=0.750,)

story = str(response)

# %% [markdown]
# generate picture

# %%
prompt = (  charecter + "is" + title + "illustration"  )
image = pipe(prompt).images[0]  # image here is in [PIL format](https://pillow.readthedocs.io/en/stable/)

# Now to display an image you can either save it such as:
image.save(f"astronaut_rides_horse.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# generate audio

# %% [markdown]
# output final:

# %%
# from elevenlabs import generate, play, set_api_key

set_api_key("be8c0c6f27d4e407c796138f9aa0222d") 
audio = generate(
    text=story,
    voice="Bella"
)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 4>:4                                                                              │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/elevenlabs/simple.py:126 in generate                     │
# │                                                                                                  │
# │   123 │   │   │   text, voice, model, stream_chunk_size, api_key=api_key                         │
# │   124 │   │   )  # noqa E501                                                                     │
# │   125 │   else:                                                                                  │
# │ ❱ 126 │   │   return TTS.generate(text, voice, model, api_key=api_key)                           │
# ...

# %%
print (story)

play(audio, notebook=True)

image
